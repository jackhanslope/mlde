# %%
from hurricanes.utils import ERA5_DATASETS_DIR
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
val_dataset = torch.load(ERA5_DATASETS_DIR / "/home/jack/docos/data/era5/datasets/delta-0" / "test_dataset_era5.pt")

# %%
wind_field = np.load("output/cncsnpp/2023-10-18T20:56:02UTC/samples/epoch-100/dataset_hurricanes/pixelmmsstanur/val/01/predictions-9e6SMJpdgxsnnRcfjPt9UY.npy")

# %% [markdown]
# `wind_field` shape is `(num_samples, channels, lat, long) = (1701, 2, 32, 56)`
#
# `channels` is `u200, v200`
#
# `u` is eastward
# `v` is northward

# %%
i = 679

# %%
u = wind_field[i, 0]
v = wind_field[i, 1]

x = np.arange(wind_field.shape[3])
y = np.arange(wind_field.shape[2])

X, Y = np.meshgrid(x, y)

plt.figure()
plt.figure(figsize=(8, 6))
plt.quiver(
    X,
    Y,
    u,
    v,
    scale=1000,
    scale_units="width",
    angles="uv",
    cmap="viridis",
);

# %%
_, (u, v) = val_dataset[i]

x = np.arange(wind_field.shape[3])
y = np.arange(wind_field.shape[2])

X, Y = np.meshgrid(x, y)

plt.figure()
plt.figure(figsize=(8, 6))
plt.quiver(
    X,
    Y,
    u,
    v,
    scale=1000,
    scale_units="width",
    angles="uv",
    cmap="viridis",
);
